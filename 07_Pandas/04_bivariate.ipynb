# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(data=df,x='age',y='class',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='class'>

# %%
sns.barplot(data=df,y='fare',x='class',hue='sex',estimator='sum')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.boxplot(data=df,x='class',y='age',hue='survived')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(data=df,x='class',y='age',hue='survived')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
x=pd.crosstab(df['class'],df['survived'])
x
# Out:
# survived    0    1
# class
# First      80  136
# Second     97   87
# Third     372  119

# %%
sns.heatmap(x,annot=True,cmap='coolwarm',fmt='.2f')
# Out:
# <Axes: xlabel='survived', ylabel='class'>

# %%
sns.stripplot(data=df,x='class',y='age',hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
df2=sns.load_dataset('iris')
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df2.head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
df2.head(10).plot(kind='bar',stacked=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df2)

# %%
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
# Scatter plot with regression line
sns.regplot(x='age', y='fare', data=df, scatter_kws={'alpha':0.5}, line_kws={"color":"red"})

# Labels and title
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot with Regression Line: Age vs Fare')

# Show plot
plt.show()

# %%
sns.scatterplot(x='age',y='fare',data=df,hue='survived',style='sex')
sns.barplot()
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df3=sns.load_dataset('tips')
df3.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(data=df3,x='total_bill',y='tip',line_kws={'color':'red'})
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(data=df3,x='total_bill',y='tip')

# %%
sns.jointplot(data=df3,x='total_bill',y='tip',hue='sex')

# %%
sns.jointplot(data=df3,x='total_bill',y='tip',kind='reg')

# %%
df3['total_bill'].corr(df3['tip'])
# Out:
# 0.6757341092113641

# %%
df4=sns.load_dataset('dowjones')
df4.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.lineplot(x='Date',y='Price',data=df4)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    649 non-null    datetime64[ns]
#  1   Price   649 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 10.3 KB

# %%
df4['Month']=df4['Date'].dt.month
df4['Year']=df4['Date'].dt.year
df4
# Out:
#           Date   Price  Month  Year
# 0   1914-12-01   55.00     12  1914
# 1   1915-01-01   56.55      1  1915
# 2   1915-02-01   56.00      2  1915
# 3   1915-03-01   58.30      3  1915
# 4   1915-04-01   66.45      4  1915
# ..         ...     ...    ...   ...
# 644 1968-08-01  883.72      8  1968
# 645 1968-09-01  922.80      9  1968
# 646 1968-10-01  955.47     10  1968
# 647 1968-11-01  964.12     11  1968
# 648 1968-12-01  965.39     12  1968
#
# [649 rows x 4 columns]

# %%
sns.lineplot(x='Date',y='Price',data=df4[(df4['Year']==1965) & (df4['Month']>=5)])
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
sns.countplot(x='class', hue='survived', data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
import pandas as pd
from statsmodels.graphics.mosaicplot import mosaic
import matplotlib.pyplot as plt
# Example data
data = {
    'gender': ['Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female'],
    'smoker': ['Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No']
}

df = pd.DataFrame(data)
# Create mosaic plot
mosaic(df, ['gender', 'smoker'], title='Mosaic Plot: Gender vs Smoker')

# Show plot
plt.show()
